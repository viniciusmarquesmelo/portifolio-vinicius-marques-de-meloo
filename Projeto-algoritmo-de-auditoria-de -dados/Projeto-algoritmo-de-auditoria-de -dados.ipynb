# %%
respostas da parte 1

resposta da pergunta 1: no meu entendimento outlier é um valor que aumenta a media so com o seu valor individual, por exemplo eu ganho 5000 e meu amigo 1100 a nossa media seia alta, mas por conta so de um valor, ou seja um conjunto de dados, onde maioria dos valores costumam ter um padrão, o outlier é aquele que fica muito distante desse padrão, é tipo um ponto fora da curva.



resposta da pergunta 2: Bom o que eu entendi com o conceito de normalização foi que eles retiram o outlier (valor que fica distante de um padrão) para ter um resultado fiel da média, pois valores acima ou abaixo do padrão, acaba atrapalhando a media, fazendo parecer que os dados são maiores (ou menores) do que realmente são na maioria dos caso



resposta da pergunta 3: no meu entendimento é o valor máximo de distorção ou erro que 0auditor está disposto a aceitar nua amostra ou saldo sem que isso comprometa a confiança ou a conclusão do trabalho, dentro de um nível de segurança apropriado para todo o relatório.



RESPOSTAS PARTE 2



# Configuração Global

LIMITE_SEGURANCA = 10000.0



# Entrada de Dados

venda1 = float(input("Digite o valor da 1ª venda: R$ "))

venda2 = float(input("Digite o valor da 2ª venda: R$ "))

venda3 = float(input("Digite o valor da 3ª venda: R$ "))



# Função de análise

def analisar_vendas(venda1, venda2, venda3):

  global LIMITE_SEGURANCA



  media = (venda1 + venda2 + venda3) / 3

  print(f"Média das vendas: R$ {media:.2f}")



  for venda in [venda1, venda2, venda3]:

    if venda > media * 5:

      print("REVISÃO MANUAL")

      resposta = input("Venda legítima? (s/n): ").lower()

      if resposta == 's':

        LIMITE_SEGURANCA = venda

RESPOSTAS PARTE 3



1; bom a media ficou elevada por conta do valor alto da venda de 5000, bom ele não retirou a venda que foge dos padrões , então não correspondeu , não conseguir chegar na solução.

2: bom pra mim usar esse tipo de sistema poderia acarretar em acontecimentos excessivos de fraude, inconsistência , falta de rastreabilidade , falhas de segurança graves

3:Pra mim foram os espaços e os "" e eu utilizei muito os exemplos disponiveis no blackboard.
# Out:
#   File "/tmp/ipykernel_21062/3508459962.py", line 11
#     resposta da pergunta 3: no meu entendimento é o valor máximo de distorção ou erro que 0auditor está disposto a aceitar nua amostra ou saldo sem que isso comprometa a confiança ou a conclusão do trabalho, dentro de um nível de segurança apropriado para todo o relatório.
#                                                                                           ^
# SyntaxError: invalid decimal literal
